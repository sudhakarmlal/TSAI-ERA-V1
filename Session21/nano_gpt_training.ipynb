# %%
import requests

url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
response = requests.get(url)

if response.status_code == 200:
    with open("input.txt", "wb") as file:
        file.write(response.content)
else:
    print("Failed to download the file. Status code:", response.status_code)

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 64 # what is the maximum context length for predictions?
max_iters = 20000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 8
n_layer = 8
dropout = 0.2
# ------------

torch.manual_seed(1337)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# 0.410945 M parameters
# step 0: train loss 4.3985, val loss 4.3979
# step 100: train loss 2.6418, val loss 2.6449
# step 200: train loss 2.5258, val loss 2.5249
# step 300: train loss 2.4548, val loss 2.4741
# step 400: train loss 2.4070, val loss 2.4063
# step 500: train loss 2.3632, val loss 2.3748
# step 600: train loss 2.3206, val loss 2.3284
# step 700: train loss 2.2758, val loss 2.2869
# step 800: train loss 2.2406, val loss 2.2538
# step 900: train loss 2.1973, val loss 2.2159
# step 1000: train loss 2.1719, val loss 2.2034
# step 1100: train loss 2.1446, val loss 2.1759
# step 1200: train loss 2.1135, val loss 2.1476
# step 1300: train loss 2.0798, val loss 2.1280
# step 1400: train loss 2.0675, val loss 2.1018
# step 1500: train loss 2.0363, val loss 2.0950
# step 1600: train loss 2.0218, val loss 2.0729
# step 1700: train loss 2.0012, val loss 2.0593
# step 1800: train loss 1.9764, val loss 2.0430
# step 1900: train loss 1.9699, val loss 2.0399
# step 2000: train loss 1.9484, val loss 2.0239
# step 2100: train loss 1.9288, val loss 2.0091
# step 2200: train loss 1.9060, val loss 1.9907
# step 2300: train loss 1.9040, val loss 1.9902
# step 2400: train loss 1.8776, val loss 1.9761
# step 2500: train loss 1.8748, val loss 1.9751
# step 2600: train loss 1.8535, val loss 1.9632
# step 2700: train loss 1.8540, val loss 1.9514
# step 2800: train loss 1.8380, val loss 1.9553
# step 2900: train loss 1.8315, val loss 1.9591
# step 3000: train loss 1.8184, val loss 1.9332
# step 3100: train loss 1.8095, val loss 1.9284
# step 3200: train loss 1.8110, val loss 1.9302
# step 3300: train loss 1.7948, val loss 1.9252
# step 3400: train loss 1.7860, val loss 1.9104
# step 3500: train loss 1.7758, val loss 1.9136
# step 3600: train loss 1.7653, val loss 1.9035
# step 3700: train loss 1.7576, val loss 1.9031
# step 3800: train loss 1.7519, val loss 1.8958
# step 3900: train loss 1.7555, val loss 1.8908
# step 4000: train loss 1.7430, val loss 1.8964
# step 4100: train loss 1.7321, val loss 1.8904
# step 4200: train loss 1.7303, val loss 1.8830
# step 4300: train loss 1.7283, val loss 1.8832
# step 4400: train loss 1.7211, val loss 1.8753
# step 4500: train loss 1.7122, val loss 1.8593
# step 4600: train loss 1.7093, val loss 1.8688
# step 4700: train loss 1.6992, val loss 1.8584
# step 4800: train loss 1.6983, val loss 1.8395
# step 4900: train loss 1.6956, val loss 1.8388
# step 5000: train loss 1.6882, val loss 1.8363
# step 5100: train loss 1.6854, val loss 1.8351
# step 5200: train loss 1.6751, val loss 1.8278
# step 5300: train loss 1.6700, val loss 1.8443
# step 5400: train loss 1.6712, val loss 1.8376
# step 5500: train loss 1.6673, val loss 1.8387
# step 5600: train loss 1.6725, val loss 1.8250
# step 5700: train loss 1.6587, val loss 1.8262
# step 5800: train loss 1.6517, val loss 1.8065
# step 5900: train loss 1.6561, val loss 1.8074
# step 6000: train loss 1.6479, val loss 1.8182
# step 6100: train loss 1.6406, val loss 1.8002
# step 6200: train loss 1.6374, val loss 1.8122
# step 6300: train loss 1.6368, val loss 1.8157
# step 6400: train loss 1.6336, val loss 1.8074
# step 6500: train loss 1.6310, val loss 1.7948
# step 6600: train loss 1.6133, val loss 1.8078
# step 6700: train loss 1.6222, val loss 1.7807
# step 6800: train loss 1.6212, val loss 1.7918
# step 6900: train loss 1.6242, val loss 1.7903
# step 7000: train loss 1.6212, val loss 1.7903
# step 7100: train loss 1.6096, val loss 1.7910
# step 7200: train loss 1.6093, val loss 1.7756
# step 7300: train loss 1.6081, val loss 1.7826
# step 7400: train loss 1.5997, val loss 1.7842
# step 7500: train loss 1.6089, val loss 1.7672
# step 7600: train loss 1.6167, val loss 1.7787
# step 7700: train loss 1.5990, val loss 1.7615
# step 7800: train loss 1.5915, val loss 1.7594
# step 7900: train loss 1.5918, val loss 1.7588
# step 8000: train loss 1.6025, val loss 1.7670
# step 8100: train loss 1.5945, val loss 1.7667
# step 8200: train loss 1.5890, val loss 1.7560
# step 8300: train loss 1.5882, val loss 1.7653
# step 8400: train loss 1.5862, val loss 1.7545
# step 8500: train loss 1.5840, val loss 1.7465
# step 8600: train loss 1.5754, val loss 1.7641
# step 8700: train loss 1.5696, val loss 1.7546
# step 8800: train loss 1.5790, val loss 1.7555
# step 8900: train loss 1.5783, val loss 1.7459
# step 9000: train loss 1.5751, val loss 1.7488
# step 9100: train loss 1.5700, val loss 1.7426
# step 9200: train loss 1.5657, val loss 1.7355
# step 9300: train loss 1.5669, val loss 1.7374
# step 9400: train loss 1.5652, val loss 1.7482
# step 9500: train loss 1.5637, val loss 1.7355
# step 9600: train loss 1.5752, val loss 1.7367
# step 9700: train loss 1.5644, val loss 1.7382
# step 9800: train loss 1.5579, val loss 1.7496
# step 9900: train loss 1.5631, val loss 1.7465
# step 10000: train loss 1.5482, val loss 1.7255
# step 10100: train loss 1.5544, val loss 1.7342
# step 10200: train loss 1.5473, val loss 1.7206
# step 10300: train loss 1.5492, val loss 1.7310
# step 10400: train loss 1.5477, val loss 1.7216
# step 10500: train loss 1.5484, val loss 1.7224
# step 10600: train loss 1.5453, val loss 1.7167
# step 10700: train loss 1.5392, val loss 1.7247
# step 10800: train loss 1.5453, val loss 1.7255
# step 10900: train loss 1.5406, val loss 1.7167
# step 11000: train loss 1.5396, val loss 1.7231
# step 11100: train loss 1.5377, val loss 1.7120
# step 11200: train loss 1.5447, val loss 1.7208
# step 11300: train loss 1.5347, val loss 1.7094
# step 11400: train loss 1.5404, val loss 1.7208
# step 11500: train loss 1.5369, val loss 1.7045
# step 11600: train loss 1.5233, val loss 1.6964
# step 11700: train loss 1.5289, val loss 1.7104
# step 11800: train loss 1.5280, val loss 1.7089
# step 11900: train loss 1.5314, val loss 1.7156
# step 12000: train loss 1.5209, val loss 1.7006
# step 12100: train loss 1.5277, val loss 1.7019
# step 12200: train loss 1.5197, val loss 1.7014
# step 12300: train loss 1.5242, val loss 1.7066
# step 12400: train loss 1.5193, val loss 1.7117
# step 12500: train loss 1.5192, val loss 1.6916
# step 12600: train loss 1.5247, val loss 1.7015
# step 12700: train loss 1.5179, val loss 1.7052
# step 12800: train loss 1.5133, val loss 1.6869
# step 12900: train loss 1.5116, val loss 1.7055
# step 13000: train loss 1.5164, val loss 1.7019
# step 13100: train loss 1.5134, val loss 1.7017
# step 13200: train loss 1.5211, val loss 1.6888
# step 13300: train loss 1.5129, val loss 1.7023
# step 13400: train loss 1.5181, val loss 1.7039
# step 13500: train loss 1.5128, val loss 1.7011
# step 13600: train loss 1.5113, val loss 1.6870
# step 13700: train loss 1.5098, val loss 1.6871
# step 13800: train loss 1.5061, val loss 1.6862
# step 13900: train loss 1.4989, val loss 1.6804
# step 14000: train loss 1.4998, val loss 1.6909
# step 14100: train loss 1.5138, val loss 1.6953
# step 14200: train loss 1.5033, val loss 1.6853
# step 14300: train loss 1.5064, val loss 1.6952
# step 14400: train loss 1.5055, val loss 1.6796
# step 14500: train loss 1.4947, val loss 1.6777
# step 14600: train loss 1.4962, val loss 1.6750
# step 14700: train loss 1.4928, val loss 1.6784
# step 14800: train loss 1.4873, val loss 1.6725
# step 14900: train loss 1.4963, val loss 1.6763
# step 15000: train loss 1.4986, val loss 1.6835
# step 15100: train loss 1.4937, val loss 1.6696
# step 15200: train loss 1.4920, val loss 1.6863
# step 15300: train loss 1.4947, val loss 1.6799
# step 15400: train loss 1.4907, val loss 1.6712
# step 15500: train loss 1.4915, val loss 1.6710
# step 15600: train loss 1.4936, val loss 1.6812
# step 15700: train loss 1.4788, val loss 1.6626
# step 15800: train loss 1.4889, val loss 1.6661
# step 15900: train loss 1.4897, val loss 1.6775
# step 16000: train loss 1.4901, val loss 1.6833
# step 16100: train loss 1.4845, val loss 1.6893
# step 16200: train loss 1.4883, val loss 1.6820
# step 16300: train loss 1.4824, val loss 1.6632
# step 16400: train loss 1.4826, val loss 1.6692
# step 16500: train loss 1.4843, val loss 1.6617
# step 16600: train loss 1.4802, val loss 1.6598
# step 16700: train loss 1.4775, val loss 1.6590
# step 16800: train loss 1.4837, val loss 1.6626
# step 16900: train loss 1.4819, val loss 1.6589
# step 17000: train loss 1.4763, val loss 1.6514
# step 17100: train loss 1.4823, val loss 1.6523
# step 17200: train loss 1.4763, val loss 1.6615
# step 17300: train loss 1.4783, val loss 1.6651
# step 17400: train loss 1.4729, val loss 1.6696
# step 17500: train loss 1.4720, val loss 1.6592
# step 17600: train loss 1.4752, val loss 1.6712
# step 17700: train loss 1.4801, val loss 1.6569
# step 17800: train loss 1.4691, val loss 1.6628
# step 17900: train loss 1.4713, val loss 1.6560
# step 18000: train loss 1.4662, val loss 1.6664
# step 18100: train loss 1.4649, val loss 1.6560
# step 18200: train loss 1.4722, val loss 1.6593
# step 18300: train loss 1.4661, val loss 1.6500
# step 18400: train loss 1.4675, val loss 1.6468
# step 18500: train loss 1.4664, val loss 1.6548
# step 18600: train loss 1.4638, val loss 1.6627
# step 18700: train loss 1.4701, val loss 1.6550
# step 18800: train loss 1.4779, val loss 1.6555
# step 18900: train loss 1.4659, val loss 1.6426
# step 19000: train loss 1.4598, val loss 1.6625
# step 19100: train loss 1.4637, val loss 1.6502
# step 19200: train loss 1.4624, val loss 1.6516
# step 19300: train loss 1.4673, val loss 1.6528
# step 19400: train loss 1.4688, val loss 1.6516
# step 19500: train loss 1.4624, val loss 1.6490
# step 19600: train loss 1.4567, val loss 1.6637
# step 19700: train loss 1.4649, val loss 1.6540
# step 19800: train loss 1.4588, val loss 1.6561
# step 19900: train loss 1.4577, val loss 1.6586
# step 19999: train loss 1.4482, val loss 1.6521

# %%
torch.save(m.state_dict(), 'model.pth')
