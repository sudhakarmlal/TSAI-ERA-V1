# %%
import torchvision.datasets

# %%
from torchvision.datasets import OxfordIIITPet

# %%
import torchvision.transforms as T
import torch.nn as nn

# %%
import torchvision.transforms.functional as TF,torch.nn.functional as F

# %%
import fastcore.all as fc

# %%
from torchvision import transforms

# %%
custom_transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize the images to a common size
    transforms.ToTensor(),           # Convert images to Torch tensors
    #transforms.Lambda(lambda x: x / 256.0),  # Normalize pixel values by dividing by 256
])

# %%
from torchvision.datasets import OxfordIIITPet
from torchvision import transforms

class CustomOxfordIIITPet(OxfordIIITPet):
    def __init__(self, root, split, target_types, custom_transform=None, **kwargs):
        super(CustomOxfordIIITPet, self).__init__(root=root, split=split, target_types=target_types, **kwargs)
        self.custom_transform = custom_transform

    def __getitem__(self, index):
        img, target = super(CustomOxfordIIITPet, self).__getitem__(index)

        if self.custom_transform is not None:
            img = self.custom_transform(img)
            target = self.custom_transform(target)

        return img, target

# Define your custom transformation
custom_transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize the images to a common size
    transforms.ToTensor(),           # Convert images to Torch tensors
    #transforms.Lambda(lambda x: x / 256.0),  # Normalize pixel values by dividing by 256
])

# Create the dataset and include the custom transform within it
train_ds = CustomOxfordIIITPet(
    root='./',
    split='trainval',
    target_types='segmentation',
    custom_transform=custom_transform,
    download=True
)

test_ds = CustomOxfordIIITPet(
    root='./',
    split='test',
    target_types='segmentation',
    custom_transform=custom_transform,
    download=True
)

# Access an item from the dataset using indexing
sample_image, sample_target = train_ds[4]

# %%
sample_image.shape,sample_target.shape
# Out:
# (torch.Size([3, 128, 128]), torch.Size([1, 128, 128]))

# %%
total_ds = train_ds+test_ds

# %%
from torch.utils.data import DataLoader, random_split

# %%
len(total_ds)
# Out:
# 7349

# %%
total_data = len(total_ds)
train_size = int(0.8 * total_data)
val_size = total_data - train_size
print(train_size,val_size)

# Use random_split to split the dataset into training and validation
train_ds, val_ds = random_split(total_ds, [train_size, val_size])
# Out:
# 5879 1470

# %%
len(train_ds),len(val_ds)
# Out:
# (5879, 1470)

# %%
from learner import *
from datasets import *
from conv import *
from training import get_dls

# %%
dls = DataLoaders(*get_dls(train_ds, val_ds, bs=256, num_workers=8))

# %%
xb,yb = next(iter(dls.train))

# %%
show_images(xb[:4], imsize=2.5)

# %%
from functools import partial

# %%
def up_block(ni, nf, ks=3, act=act_gr):
    return nn.Sequential(nn.UpsamplingNearest2d(scale_factor=2),
                         ResBlock(ni, nf, ks=ks, act=act))

# %%
import torch.nn as nn

class ContractingBlock(nn.Module):
    def __init__(self, in_channels, out_channels,max_pooling=True):
        super(ContractingBlock, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu1 = nn.ReLU(inplace=True)
        
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.relu2 = nn.ReLU(inplace=True)
        self.pool = fc.noop if (not max_pooling) else nn.AvgPool2d(2, ceil_mode=True)
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        
        skip = x  # store the output for the skip connection
        x = self.pool(x)
        
        return x, skip

class ExpandingBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ExpandingBlock, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu1 = nn.ReLU(inplace=True)
        
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.relu2 = nn.ReLU(inplace=True)
        
        
        self.upsample = nn.ConvTranspose2d(in_channels, in_channels//2, kernel_size=2, stride=2)
        
    def forward(self, x,skip=None):
        
        x = self.upsample(x)
        x = torch.cat((x, skip), dim=1)
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu1(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu2(x)
        
        
        
        return x
    
class UNet(nn.Module):
    def __init__(self,in_channels=3, n_filters=32, n_classes=3):
        super(UNet, self).__init__()
        
        self.contract1 = ContractingBlock(in_channels, n_filters,max_pooling=True) 
        self.contract2 = ContractingBlock(n_filters, n_filters*2,max_pooling=True)
        self.contract3 = ContractingBlock( n_filters*2,  n_filters*4,max_pooling=True)
        self.contract4 = ContractingBlock( n_filters*4,  n_filters*8,max_pooling=True)
        self.contract5 = ContractingBlock( n_filters*8,  n_filters*16,max_pooling=False)
        
        self.expand1 = ExpandingBlock(n_filters*16, n_filters*8)
        self.expand2 = ExpandingBlock(n_filters*8, n_filters*4)
        self.expand3 = ExpandingBlock(n_filters*4, n_filters*2)
        self.expand4 = ExpandingBlock(n_filters*2, n_filters)
        
        self.pen_conv = conv(n_filters, n_classes, stride=1, act=True, ks=3)
        
        self.final_conv = conv(n_classes,1, stride=1, act=False, ks=1)
        
    def forward(self, x):
        # Contracting path
        x, skip1 = self.contract1(x)
        x, skip2 = self.contract2(x)
        x, skip3 = self.contract3(x)
        x, skip4 = self.contract4(x)
        x, _ = self.contract5(x)
        
        # Expanding path
        x = self.expand1(x, skip4)
        x = self.expand2(x, skip3)
        x = self.expand3(x, skip2)
        x = self.expand4(x, skip1)
        
        x =  self.pen_conv(x)
        return self.final_conv(x)

# %%
model = UNet()

# %%
import torch

# %%
x = torch.randn(512,3,128,128)

# %%
y = model(x)

# %%
y.shape
# Out:
# torch.Size([512, 1, 128, 128])

# %%
import torch
class MixedPrecision(TrainCB):
    order = DeviceCB.order+10

    def before_fit(self, learn): self.scaler = torch.cuda.amp.GradScaler()

    def before_batch(self, learn):
        self.autocast = torch.autocast("cuda", dtype=torch.float16)
        self.autocast.__enter__()

    def after_loss(self, learn): self.autocast.__exit__(None, None, None)

    def backward(self, learn): self.scaler.scale(learn.loss).backward()

    def step(self, learn):
        self.scaler.step(learn.opt)
        self.scaler.update()

# %%
from torch import optim
from functools import partial
from torch import optim

# %%
metrics = MetricsCB()
cbs = [DeviceCB(), metrics, ProgressCB(plot=True), MixedPrecision()]
lr_cbs = [DeviceCB(), ProgressCB(), MixedPrecision()]
opt_func = partial(optim.AdamW, eps=1e-5)

# %%
import sys,gc,traceback
import fastcore.all as fc

# %%
# %% ../nbs/11_initializing.ipynb 11
def clean_ipython_hist():
    # Code in this function mainly copied from IPython source
    if not 'get_ipython' in globals(): return
    ip = get_ipython()
    user_ns = ip.user_ns
    ip.displayhook.flush()
    pc = ip.displayhook.prompt_count + 1
    for n in range(1, pc): user_ns.pop('_i'+repr(n),None)
    user_ns.update(dict(_i='',_ii='',_iii=''))
    hm = ip.history_manager
    hm.input_hist_parsed[:] = [''] * pc
    hm.input_hist_raw[:] = [''] * pc
    hm._i = hm._ii = hm._iii = hm._i00 =  ''

# %% ../nbs/11_initializing.ipynb 12
def clean_tb():
    # h/t Piotr Czapla
    if hasattr(sys, 'last_traceback'):
        traceback.clear_frames(sys.last_traceback)
        delattr(sys, 'last_traceback')
    if hasattr(sys, 'last_type'): delattr(sys, 'last_type')
    if hasattr(sys, 'last_value'): delattr(sys, 'last_value')

# %% ../nbs/11_initializing.ipynb 13
def clean_mem():
    clean_tb()
    clean_ipython_hist()
    gc.collect()
    torch.cuda.empty_cache()

# %%
clean_mem()

# %%
from torch.optim import lr_scheduler

# %%
class BaseSchedCB(Callback):
    def __init__(self, sched): self.sched = sched
    def before_fit(self, learn): self.schedo = self.sched(learn.opt)
    def _step(self, learn):
        if learn.training: self.schedo.step()

# %%
class BatchSchedCB(BaseSchedCB):
    def after_batch(self, learn): self._step(learn)

# %%
def dice_loss(pred, target):
    smooth = 1e-5
    
    # flatten predictions and targets
    pred = pred.view(-1)
    target = target.view(-1)
    
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum()
    
    dice = (2. * intersection + smooth) / (union + smooth)
    
    return 1 - dice

# %%
epochs = 20
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched)]
learn = Learner(model, dls, dice_loss, lr=lr, cbs=cbs+xtra, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>loss</th>
#       <th>epoch</th>
#       <th>train</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.984</td>
#       <td>0</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>0</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>1</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>1</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.987</td>
#       <td>2</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.985</td>
#       <td>2</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>3</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>3</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>4</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>4</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>5</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.987</td>
#       <td>5</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>6</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>6</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>7</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>7</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>8</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.986</td>
#       <td>8</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>9</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>9</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>10</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.984</td>
#       <td>10</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>11</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>11</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.982</td>
#       <td>12</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.982</td>
#       <td>12</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.981</td>
#       <td>13</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.981</td>
#       <td>13</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.981</td>
#       <td>14</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.983</td>
#       <td>14</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>15</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.981</td>
#       <td>15</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>16</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>16</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>17</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>17</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>18</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>18</td>
#       <td>eval</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>19</td>
#       <td>train</td>
#     </tr>
#     <tr>
#       <td>0.980</td>
#       <td>19</td>
#       <td>eval</td>
#     </tr>
#   </tbody>
# </table>

# %%
from torchmetrics import Dice
dice = Dice()

# %%
metrics = MetricsCB(dice=Dice()))

# %%
epochs = 20
lr = 1e-2
tmax = epochs * len(dls.train)
sched = partial(lr_scheduler.OneCycleLR, max_lr=lr, total_steps=tmax)
xtra = [BatchSchedCB(sched)]
learn = Learner(model, dls, dice, lr=lr, cbs=cbs+xtra, opt_func=opt_func)

# %%
learn.fit(epochs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/20 00:00&lt;?]
#     </div>
#
#
#
#     <div>
#       <progress value='0' class='' max='23' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/23 00:00&lt;?]
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 learn.fit(epochs)
#
# File /notebooks/S18/learner.py:178, in Learner.fit(self, n_epochs, train, valid, cbs, lr)
#     176     if lr is None: lr = self.lr
#     177     if self.opt_func: self.opt = self.opt_func(self.model.parameters(), lr)
# --> 178     self._fit(train, valid)
#     179 finally:
#     180     for cb in cbs: self.cbs.remove(cb)
#
# File /notebooks/S18/learner.py:129, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     127 try:
#     128     o.callback(f'before_{self.nm}')
# --> 129     f(o, *args, **kwargs)
#     130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File /notebooks/S18/learner.py:166, in Learner._fit(self, train, valid)
#     163 @with_cbs('fit')
#     164 def _fit(self, train, valid):
#     165     for self.epoch in self.epochs:
# --> 166         if train: self.one_epoch(True)
#     167         if valid: torch.no_grad()(self.one_epoch)(False)
#
# File /notebooks/S18/learner.py:161, in Learner.one_epoch(self, training)
#     159 self.model.train(training)
#     160 self.dl = self.dls.train if training else self.dls.valid
# --> 161 self._one_epoch()
#
# File /notebooks/S18/learner.py:129, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     127 try:
#     128     o.callback(f'before_{self.nm}')
# --> 129     f(o, *args, **kwargs)
#     130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File /notebooks/S18/learner.py:156, in Learner._one_epoch(self)
#     154 @with_cbs('epoch')
#     155 def _one_epoch(self):
# --> 156     for self.iter,self.batch in enumerate(self.dl): self._one_batch()
#
# File /notebooks/S18/learner.py:129, in with_cbs.__call__.<locals>._f(o, *args, **kwargs)
#     127 try:
#     128     o.callback(f'before_{self.nm}')
# --> 129     f(o, *args, **kwargs)
#     130     o.callback(f'after_{self.nm}')
#     131 except globals()[f'Cancel{self.nm.title()}Exception']: pass
#
# File /notebooks/S18/learner.py:145, in Learner._one_batch(self)
#     143 self.predict()
#     144 self.callback('after_predict')
# --> 145 self.get_loss()
#     146 self.callback('after_loss')
#     147 if self.training:
#
# File /notebooks/S18/learner.py:186, in Learner.callback(self, method_nm)
# --> 186 def callback(self, method_nm): run_cbs(self.cbs, method_nm, self)
#
# File /notebooks/S18/learner.py:35, in run_cbs(cbs, method_nm, learn)
#      33 for cb in sorted(cbs, key=attrgetter('order')):
#      34     method = getattr(cb, method_nm, None)
# ---> 35     if method is not None: method(learn)
#
# File /notebooks/S18/learner.py:87, in TrainCB.get_loss(self, learn)
# ---> 87 def get_loss(self, learn): learn.loss = learn.loss_func(learn.preds, *learn.batch[self.n_inp:])
#
# File /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.9/site-packages/torchmetrics/metric.py:298, in Metric.forward(self, *args, **kwargs)
#     296     self._forward_cache = self._forward_full_state_update(*args, **kwargs)
#     297 else:
# --> 298     self._forward_cache = self._forward_reduce_state_update(*args, **kwargs)
#     300 return self._forward_cache
#
# File ~/.local/lib/python3.9/site-packages/torchmetrics/metric.py:367, in Metric._forward_reduce_state_update(self, *args, **kwargs)
#     364 self._enable_grad = True  # allow grads for batch computation
#     366 # calculate batch state and compute batch value
# --> 367 self.update(*args, **kwargs)
#     368 batch_val = self.compute()
#     370 # reduce batch and global state
#
# File ~/.local/lib/python3.9/site-packages/torchmetrics/metric.py:457, in Metric._wrap_update.<locals>.wrapped_func(*args, **kwargs)
#     455 with torch.set_grad_enabled(self._enable_grad):
#     456     try:
# --> 457         update(*args, **kwargs)
#     458     except RuntimeError as err:
#     459         if "Expected all tensors to be on" in str(err):
#
# File ~/.local/lib/python3.9/site-packages/torchmetrics/classification/dice.py:209, in Dice.update(self, preds, target)
#     206 @no_type_check
#     207 def update(self, preds: Tensor, target: Tensor) -> None:
#     208     """Update state with predictions and targets."""
# --> 209     tp, fp, tn, fn = _stat_scores_update(
#     210         preds,
#     211         target,
#     212         reduce=self.reduce,
#     213         mdmc_reduce=self.mdmc_reduce,
#     214         threshold=self.threshold,
#     215         num_classes=self.num_classes,
#     216         top_k=self.top_k,
#     217         multiclass=self.multiclass,
#     218         ignore_index=self.ignore_index,
#     219     )
#     221     # Update states
#     222     if self.reduce != AverageMethod.SAMPLES and self.mdmc_reduce != MDMCAverageMethod.SAMPLEWISE:
#
# File ~/.local/lib/python3.9/site-packages/torchmetrics/functional/classification/stat_scores.py:956, in _stat_scores_update(preds, target, reduce, mdmc_reduce, num_classes, top_k, threshold, multiclass, ignore_index, mode)
#     953     preds, target = _drop_negative_ignored_indices(preds, target, ignore_index, mode)
#     954     _negative_index_dropped = True
# --> 956 preds, target, _ = _input_format_classification(
#     957     preds,
#     958     target,
#     959     threshold=threshold,
#     960     num_classes=num_classes,
#     961     multiclass=multiclass,
#     962     top_k=top_k,
#     963     ignore_index=ignore_index,
#     964 )
#     966 if ignore_index is not None and ignore_index >= preds.shape[1]:
#     967     raise ValueError(f"The `ignore_index` {ignore_index} is not valid for inputs with {preds.shape[1]} classes")
#
# File ~/.local/lib/python3.9/site-packages/torchmetrics/utilities/checks.py:414, in _input_format_classification(preds, target, threshold, top_k, num_classes, multiclass, ignore_index)
#     411 if preds.dtype == torch.float16:
#     412     preds = preds.float()
# --> 414 case = _check_classification_inputs(
#     415     preds,
#     416     target,
#     417     threshold=threshold,
#     418     num_classes=num_classes,
#     419     multiclass=multiclass,
#     420     top_k=top_k,
#     421     ignore_index=ignore_index,
#     422 )
#     424 if case in (DataType.BINARY, DataType.MULTILABEL) and not top_k:
#     425     preds = (preds >= threshold).int()
#
# File ~/.local/lib/python3.9/site-packages/torchmetrics/utilities/checks.py:270, in _check_classification_inputs(preds, target, threshold, num_classes, multiclass, top_k, ignore_index)
#     216 """Perform error checking on inputs for classification.
#     217
#     218 This ensures that preds and target take one of the shape/type combinations that are
#    (...)
#     267
#     268 """
#     269 # Basic validation (that does not need case/type information)
# --> 270 _basic_input_validation(preds, target, threshold, multiclass, ignore_index)
#     272 # Check that shape/types fall into one of the cases
#     273 case, implied_classes = _check_shape_and_type_consistency(preds, target)
#
# File ~/.local/lib/python3.9/site-packages/torchmetrics/utilities/checks.py:56, in _basic_input_validation(preds, target, threshold, multiclass, ignore_index)
#      53     return
#      55 if target.is_floating_point():
# ---> 56     raise ValueError("The `target` has to be an integer tensor.")
#      58 if (ignore_index is None and target.min() < 0) or (ignore_index and ignore_index >= 0 and target.min() < 0):
#      59     raise ValueError("The `target` has to be a non-negative tensor.")
#
# ValueError: The `target` has to be an integer tensor.

# %%
len(val_ds)
# Out:
# 1470

# %%
device = 'cuda'
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
# Results of Validation Dataset
def VisualizeResults(index):
    img,actual_mask = val_ds[index]
    img = img.unsqueeze(0)
    pred_y = model(img.to(device))
    #pred_mask = tf.argmax(pred_y[0], axis=-1)
    #pred_mask = pred_mask[..., tf.newaxis]
    fig, arr = plt.subplots(1, 3, figsize=(15, 15))
    show_image(img.squeeze(),ax = arr[0])
    arr[0].set_title('Processed Image')
    show_image(actual_mask,arr[1])
    arr[1].set_title('Actual Masked Image ')
    show_image(pred_y.squeeze(),arr[2])
    arr[2].set_title('Predicted Masked Image ')

# %%
# Add any index to contrast the predicted mask with actual mask
index = 700
VisualizeResults(index)
